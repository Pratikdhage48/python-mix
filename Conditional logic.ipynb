# %%
10 * False
# Out:
# 0

# %%
not True * 10
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
len('word') < len('word')
# Out:
# True

# %%
len('word') >= len('worrds')
# Out:
# False

# %%
greater_than_five = 7 > 5
greater_than_five
# Out:
# True

# %% [markdown]
# ## if

# %%
price =  100

if price < 500:
    print("Discount not applicable")
    
print("Thank you")
# Out:
# Discount not
# Thank you

# %%
price =  600

if price < 500:
    print("Discount not applicable")
    
print("Thank you")
# Out:
# Thank you

# %% [markdown]
# ## else

# %%
price =  100
dicount_range = 500

if price > 500:
    print("Discount applied")
else:
    print("Thank you for shopping")
# Out:
# Thank you for shopping

# %%
price =  600
dicount_range = 500

if price > 500:
    print("Discount applied")
else:
    print("Thank you for shopping")
# Out:
# Discount applied

# %% [markdown]
# ## elif

# %%
price =  400
dicount_range = 500
combo_off = 300

if price > 500:
    print("Discount applied")
elif price > combo_off:
    print("Combo-off applied")

else:
    print("Thank you for shopping")
# Out:
# Combo-off applied

# %%
price =  600
dicount_range = 500
combo_off = 300

if price > 500:
    print(f"Discount applied")
elif price > combo_off:
    print(f"Combo-off applied")

else:
    print(f"Thank you for shopping")
# Out:
# Discount applied

# %%
customer_id = 'A00051'

# %%
int(customer_id.strip('A'))
# Out:
# 51

# %%
if int(customer_id.strip('A')) <= 50:
    print("You get Big price")
elif int(customer_id.strip('A')) <= 100:
    print("You  get Small price")
else:
    print("Better luck next time")
    
print("Thank you for shopping")
# Out:
# You  get Small price
# Thank you for shopping

# %%
if 50 < int(customer_id.strip('A')) <= 100:
    print("You get small price")
elif int(customer_id.strip('A')) <= 50:
    print("You  get Big price")
else:
    print("Better luck next time")
    
print("Thank you for shopping")
# Out:
# You get small price
# Thank you for shopping
