# %%
# Count positive number

number = [4, -2, 6, 1, -8, -21, 9, -33, 18, -3]

posivie_count = 0

for num in number:
    if num > 0:
        posivie_count += 1
print(posivie_count)
# Out:
# 5

# %%
number = [4, -2, 6, 1, -8, -21, 9, -33, 18, -3]

for num in number:
    if num > 0:
        print(num)
# Out:
# 4
# 6
# 1
# 9
# 18

# %%
# Sum of even number up to given number n

n = 10
sum_even_number = 0

for i in range(1,n+1):
    if i % 2 == 0:
        sum_even_number += i
print("sum of  even number is: ",sum_even_number)
# Out:
# sum of  even number is:  30

# %%
n = 10
sum_even = 0

for i in range(1, n+1):
    if i % 2 == 0:
        sum_even += 1  # here we counting even number

print("Sum of even number is: ", sum_even)
# Out:
# Sum of even number is:  5

# %%
# Print  mumtiplication table of given number up to 10, but skip the 5th iteration

number = 3

for i in range(1, 11):
    if i == 5:
        continue
    print(f" {number} x {i} = ", number*i)
# Out:
#  3 x 1 =  3
#  3 x 2 =  6
#  3 x 3 =  9
#  3 x 4 =  12
#  3 x 6 =  18
#  3 x 7 =  21
#  3 x 8 =  24
#  3 x 9 =  27
#  3 x 10 =  30

# %%
# Reverse a string using loop

string = "Python"
reverse = ""

for char in string:
    reverse = char + reverse
print(reverse)
# Out:
# nohtyP

# %%
# Find the first non-repeated charector

input_str = "teeter"

for char in input_str:
    if input_str.count(char) == 1:
        print("Non-repeated char is : ", char)
        break
# Out:
# Non-repeated char is :  r

# %%
# Find the first non-repeated charector

input_str = "teeteradad"

for char in input_str:
    print(char)
    if input_str.count(char) == 1:
        print("Non-repeated char is : ", char)
        break
# Out:
# t
# e
# e
# t
# e
# r
# Non-repeated char is :  r

# %%
# Calculate the factorial of a number using while loop

number = 5

factorial = 1

while number > 0:
    factorial *= number
    number-=1
    
print("factorial value of number is: ", factorial)
# Out:
# factorial value of number is:  120

# %%
# Keep asking user fot input until they enter a number between 1 to 10

while True:

    number = int(input("Enter a number between 1 to 10:  "))
    if 1 <= number <= 10:
        print("Thanks")
        break
    else:
        print("Invalid Number, try again")
# Out:
# Enter a number between 1 to 10:   -1
# Invalid Number, try again
# Enter a number between 1 to 10:   2
# Thanks

# %%
# Keep asking user fot input until they enter a number between 1 to 10

while True:
    try:
        number = int(input("Enter a number between 1 to 10:  "))
        if 1 <= number <= 10:
            print("Thanks")
            break
    except:
        print("Invalid - It must be a 'Number', try again")
# Out:
# Enter a number between 1 to 10:   12
# Enter a number between 1 to 10:
# Invalid - It must be a 'Number', try again
# Enter a number between 1 to 10:   41
# Enter a number between 1 to 10:   12
# Enter a number between 1 to 10:
# Invalid - It must be a 'Number', try again
# Enter a number between 1 to 10:   3
# Thanks

# %%
# Check if  number is a prime number

number = 29
it_prime = True

if number > 1:
    for i in range(2, number):
        if number % i == 0:
            it_prime = False
            break
print(it_prime)
# Out:
# True

# %%
# Check if  number is a prime number

number = 29

if number > 1:
    for i in range(2, number):
        if number % i == 0:
            print("Not Prime")
            break
    else:
        print("Prime")
else:
    print("Not Prime")
# Out:
# Prime

# %%
# Check if all elements in a list are unique. If a duplicate is found, exit the loop and print the duplicate

items = ["apple", "banana", "orange", "apple", "mango"]

unique_item = set()

for item in items:
    if item in unique_item:
        print("Duplicate item is:", item)
        break
    unique_item.add(item)
# Out:
# Duplicate item is: apple

# %%
# Implement an exponential backoff strategy that doubles the wait time between retries, starting from 1 second, but stops after 5 retries

import time

wait_time = 1
max_retries = 5
attempts = 0

while attempts < max_retries:
    print("attempts", attempts + 1, "wait_time", wait_time)
    time.sleep(wait_time)
    wait_time *= 2
    attempts += 1
# Out:
# attempts 1 wait_time 1
# attempts 2 wait_time 2
# attempts 3 wait_time 4
# attempts 4 wait_time 8
# attempts 5 wait_time 16
